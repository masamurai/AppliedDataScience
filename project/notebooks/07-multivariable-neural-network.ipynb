# %% [markdown]
# https://machinelearningmastery.com/develop-first-xgboost-model-python-scikit-learn/

# %% [markdown]
# ### Load packages

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# C:\Users\m187531\AppData\Local\conda\conda\envs\my_root\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from pandas import set_option
set_option('display.max_columns', None)

# %% [markdown]
# ### Define functions

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Load dataset

# %%
# Load dataset
dataset_all = read_csv('../data/df_clean.csv', header=0)

# %%
# Subset to one country
dataset = dataset_all[dataset_all.Country == 'Japan'].sort_values('Year').reset_index().iloc[:,3:]

# %%
dataset.shape
# Out:
# (23, 21)

# %%
values = dataset.values

# %%
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
# specify the number of lag years
n_years_lag = 1
n_features = scaled.shape[1]-1
# frame as supervised learning
reframed = series_to_supervised(values, n_years_lag, 1)
print(reframed.shape)
# Out:
# (22, 42)

# %%
reframed
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   13.590583  1082.6554  1331.1099  2180.5838  2356.9458   564.8382
# 2   12.783167  1088.2812  1361.4418  2313.0267  2344.4087   608.9425
# 3   12.484250  1098.1753  1396.1105  2435.1576  2182.1631   630.3430
# 4   12.055167  1089.8927  1416.2305  2669.3172  2012.0671   653.2915
# 5   13.229750  1140.8671  1493.4250  2795.5539  1813.8055   688.6269
# 6   12.475417  1152.8119  1537.4246  3124.2287  1791.3193   743.8814
# 7   12.082833  1167.7661  1578.3839  3116.8525  1771.5196   782.3093
# 8   12.752417  1160.3747  1592.5605  3161.5961  1687.1812   825.2656
# 9   13.244750  1126.3275  1492.8235  3266.7809  1682.8814   840.6924
# 10  13.080083  1165.9829  1567.9684  3185.4882  1740.3991   905.4439
# 11  12.833833  1181.6503  1638.9020  3383.6875  1768.2282   942.1554
# 12  12.450000  1169.0059  1640.6197  3572.0973  1791.1099   958.9096
# 13  12.837333  1204.5236  1667.9168  3858.5704  1798.4067   994.2326
# 14  12.507000  1210.1157  1677.9967  4482.1984  1859.0358  1017.5585
# 15  13.435667  1205.9232  1693.9345  5207.5749  1876.5457  1095.0190
# 16  12.555917  1212.3681  1695.4858  5890.7037  1876.2620  1153.7488
# 17  12.757083  1197.1920  1688.6358  6529.1685  1956.1099  1232.0898
# 18  13.192167  1240.1671  1743.4205  7146.8460  1970.4831  1351.1329
# 19  12.874917  1151.8979  1666.3175  7306.1056  1991.3255  1439.2974
# 20  12.933833  1087.2478  1614.1553  7845.4218  1889.7947  1617.0823
# 21  13.215583  1137.4973  1711.9264  8614.9599  1987.5462  1705.6922
# 22  12.737750  1191.2801  1788.8833  9510.9401  2081.1172  1795.1289
#
#     var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)  var11(t-1)  var12(t-1)  \
# 1    443.9216  2600.5047  5883.0587         0.0    247.7112         0.0
# 2    483.4684  2609.8994  5888.3920         0.0    242.3806         0.0
# 3    502.8270  2575.3073  5949.2685         0.0    238.8828         0.0
# 4    504.7714  2568.9340  6054.6914         0.0    246.4840         0.0
# 5    541.0427  2573.8024  6143.4741         0.0    252.0788         0.0
# 6    562.8012  2587.9991  6206.6392         0.0    264.2714         0.0
# 7    581.4807  2697.0634  6395.4411         0.0    274.0647         0.0
# 8    600.1348  2639.2896  6581.5856         0.0    289.0099         0.0
# 9    622.6385  2633.7315  6648.3163         0.0    296.5964         0.0
# 10   661.9925  2603.0604  6662.1500         0.0    278.5529         0.0
# 6   274.0647       0.0  265.9245       0.0       0.0  125757000.0
# 7   289.0099       0.0  284.8526       0.0       0.0  126057000.0
# 8   296.5964       0.0  294.0935       0.0       0.0  126400000.0
# 9   278.5529       0.0  303.8107       0.0       0.0  126631000.0
# 10  284.8100       0.0  315.6212       0.0       0.0  126843000.0
# 11  320.8030       0.0  323.0267       0.0       0.0  127149000.0
# 12  331.3948       0.0  320.9944       0.0       0.0  127445000.0
# 13  353.0483       0.0  312.3002       0.0       0.0  127718000.0
# 14  380.8331       0.0  329.5981       0.0       0.0  127761000.0
# 15  378.2757       0.0  334.3279       0.0       0.0  127773000.0
# 16  380.2657       0.0  338.2993       0.0       0.0  127854000.0
# 17  398.2440       0.0  356.3927       0.0       0.0  128001000.0
# 18  429.9224       0.0  377.7368       0.0       0.0  128063000.0
# 19  405.2934       0.0  356.4585       0.0       0.0  128047000.0
# 20  412.1554       0.0  404.4198       0.0       0.0  128070000.0
# 21  400.1486       0.0  424.7568       0.0       0.0  127833000.0
# 22  413.4498       0.0  459.4648       0.0       0.0  127629000.0
#
#        var17(t)  var18(t)   var19(t)   var20(t)  var21(t)
# 1   2051.952488     1.530  64.449997  23.693268  249426.0
# 2   2166.038128     1.502  65.152792  24.684320  249352.0
# 3   2294.106358     1.458  61.273173  27.272300  249278.0
# 4   2481.282920     1.500  64.390485  27.616489  249204.0
# 5   2655.748233     1.422  61.452946  29.130731  249130.0
# 6   2839.747068     1.425  61.199215  29.654576  249056.0
# 7   3034.897078     1.388  59.517549  30.628368  248982.0
# 8   3155.309900     1.384  58.333150  31.732799  248908.0
# 9   3385.848708     1.342  61.123206  29.647275  248834.0
# 10  3582.186705     1.359  61.277631  29.597589  248760.0
# 11  3788.213052     1.330  61.180410  29.850699  248878.0
# 12  4012.427673     1.320  64.260455  27.027542  248996.0
# 13  4255.861752     1.290  67.770264  22.203279  249114.0
# 14  4526.436482     1.290  64.750591  25.446555  249232.0
# 15  4848.156050     1.260  64.589570  26.984633  249350.0
# 16  5266.031526     1.320  63.669128  26.842760  249412.0
# 17  5666.082926     1.340  68.887155  22.874384  249474.0
# 18  6109.448405     1.370  67.726093  23.442079  249536.0
# 19  6567.765473     1.370  64.613911  26.184773  249598.0
# 20  7127.792630     1.390  63.922017  25.296004  249660.0
# 21  7700.771123     1.390  78.741252   9.477442  249644.0
# 22  8318.856828     1.410  86.972988   1.509509  249628.0

# %%
# split into train and test sets
values = reframed.values
n_years = 21
train = values[:-n_years_test, :]
test = values[-n_years_test:, :]

# %%
len(train)
# Out:
# 21

# %%
# split into input and outputs
train_X, train_y = train[:, 1:], train[:, 0]
test_X, test_y = test[:, 1:], test[:, 0]
print(train_X.shape, len(train_X), train_y.shape)
# Out:
# (21, 41) 21 (21,)

# %%
train_X.shape[0]
# Out:
# 21

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_years, n_features))
test_X = test_X.reshape((test_X.shape[0], n_years, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c27075a94e12> in <module>()
#       1 # reshape input to be 3D [samples, timesteps, features]
# ----> 2 train_X = train_X.reshape((train_X.shape[0], n_years, n_features))
#       3 test_X = test_X.reshape((test_X.shape[0], n_years, n_features))
#       4 print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
#
# ValueError: cannot reshape array of size 861 into shape (21,21,20)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -7:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -7:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
