# %%
#Install the proper libraries needed
# !pip install Pillow
# !pip install matplotlib
# !pip install py2neo==2.0
# !pip install boto3
# !pip install jgraph

from PIL import Image
import webbrowser
import datetime
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
import json
from pprint import pprint
import boto3
import jgraph
from py2neo import Graph, authenticate, Relationship
import urllib
from scripts.rekgraph import rekrelationships
# %matplotlib inline
# Out:
# Requirement already satisfied: Pillow in /home/ubuntu/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: olefile in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from Pillow)
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /home/ubuntu/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: numpy>=1.7.1 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: six>=1.10 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: python-dateutil in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: functools32 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: subprocess32 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: pytz in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from matplotlib)
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: py2neo==2.0 in /home/ubuntu/anaconda2/lib/python2.7/site-packages
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: boto3 in /home/ubuntu/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: botocore<1.13.0,>=1.12.9 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: futures<4.0.0,>=2.2.0; python_version == "2.6" or python_version == "2.7" in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from s3transfer<0.2.0,>=0.1.10->boto3)
# Requirement already satisfied: docutils>=0.10 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from botocore<1.13.0,>=1.12.9->boto3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from botocore<1.13.0,>=1.12.9->boto3)
# Requirement already satisfied: urllib3<1.24,>=1.20 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from botocore<1.13.0,>=1.12.9->boto3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.9->boto3)
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: jgraph in /home/ubuntu/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: ipython in /home/ubuntu/anaconda2/lib/python2.7/site-packages (from jgraph)
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#retrieve and print a selected image
#use the same file name for each temp image or you will start getting a ton of photos
#stored in the folder
# urllib.urlretrieve("https://images-na.ssl-images-amazon.com/images/M/MV5BNDgwNjI5MzY3Ml5BMl5BanBnXkFtZTgwNDE5NTAzMTI@._V1_SY1000_CR0,0,674,1000_AL_.jpg", "images/image1.jpg")
# urllib.urlretrieve("https://www.imdb.com/name/nm0001570/mediaviewer/rm1268152576", "images/image1.jpg")
imshow(np.asarray(Image.open('images/edward_norton.jpg', 'r')))

# %%
#detect faces in the first picture in the image
client = boto3.client('rekognition', region_name='us-east-1')
response = client.detect_faces(
    Image={
        'Bytes': open('images/edward_norton.jpg','rb').read().strip()
    }
)
#the api returns a json dictionary of length 3
print('data type and length of the response from the detect_faces call')
print(type(response))
print(len(response))
 
#parsing out that dictionary
#print (response['ResponseMetadata'])
#print()
#print (response['FaceDetails'])
#print()
#print (response['OrientationCorrection'])
 
#print how many faces are in this picture
print('the number of faces detected in the picture')
faceCount=len(response['FaceDetails'])
print(faceCount)
 
if(faceCount>0):
    #next step is to show only the cropped faces
    #the IndexFaces api call will automatically take care of this parsing
    #for you when sending pictures with multiple faces to a FaceCollection.
    print('printing face bounding boxes below')
    counter=0
    #which of the faces from the photo do you want to print? rekognition makes the
    #largest face equal to index zero
    faceNumToKeep=0
    #these toKeep____ variables are to give flexibility
    #on which face to crop and print
    toKeepLeft=0.0
    toKeepTop=0.0
    toKeepWidth=0.0
    toKeepHeight=0.0
 
    #if you care to see the raw data that we parse in the for loop below
    #boundingBox=response['FaceDetails'][0]['BoundingBox']
    #print(boundingBox)
 
    #loop over each face and print the bounding boxes, save the one
    #specified by the faceNumToKeep param
    #for pictures with multiple faces, Rekognition starts with the largest face and moves iteratively to smaller ones
    for x in response['FaceDetails']:
        print('\nface number '+str(counter))
        boundingBox=x['BoundingBox']
        #print(boundingBox)
        print(boundingBox['Left'])
        print(boundingBox['Top'])
        print(boundingBox['Width'])
        print(boundingBox['Height'])
        if (counter==faceNumToKeep):
            toKeepLeft=boundingBox['Left']
            toKeepTop=boundingBox['Top']
            toKeepWidth=boundingBox['Width']
            toKeepHeight=boundingBox['Height']
        counter=counter+1
   
    #retrieve the whole photo, crop the face of interest and print                                                                 
    pil_im = Image.open('images/edward_norton.jpg', 'r')
   
    picwidth=pil_im.size[0]
    picheight=pil_im.size[1]
    print('width '+str(picwidth))
    print('height '+str(picheight))
    imshow(np.asarray(pil_im.crop((
        picwidth*toKeepLeft,
        picheight*toKeepTop,
        picwidth*toKeepLeft+picwidth*toKeepWidth,
        picheight*toKeepTop+picheight*toKeepHeight
                             ))))
# Out:
# data type and length of the response from the detect_faces call
# <type 'dict'>
# 3
# the number of faces detected in the picture
# 1
# printing face bounding boxes below
#
# face number 0
# 0.27487179637
# 0.145641028881
# 0.373333334923
# 0.373333334923
# width 375
# height 375

# %%
#detect celebrities
response = client.recognize_celebrities(
    Image={
        'Bytes': open('images/edward_norton.jpg','rb').read().strip()
    }
)

print ('num celebrities found: '+str(len(response['CelebrityFaces'])))
for i in response['CelebrityFaces']:
    print i['Name']
    imageName = i['Name']
name1=response['CelebrityFaces'][0]['Name']
# Out:
# num celebrities found: 1
# Edward Norton

# %%
authenticate("localhost:7474", "neo4j", "password")
graph = Graph()
graph.neo4j_version
# Out:
# ---------------------------------------------------------------------------
# SocketError                               Traceback (most recent call last)
# <ipython-input-22-ce034769f67e> in <module>()
#       1 authenticate("localhost:7474", "neo4j", "password")
# ----> 2 graph = Graph()
#       3 graph.neo4j_version
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/core.pyc in __new__(cls, uri)
#     524     def __new__(cls, uri=None):
#     525         if uri is None:
# --> 526             uri = ServiceRoot().graph.uri.string
#     527         if not uri.endswith("/"):
#     528             uri += "/"
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/core.pyc in graph(self)
#     450         """
#     451         if self.__graph is None:
# --> 452             self.__graph = Graph(self.resource.metadata["data"])
#     453         return self.__graph
#     454
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/core.pyc in metadata(self)
#     196             if self.__initial_metadata is not None:
#     197                 return self.__initial_metadata
# --> 198             self.get()
#     199         return self.__last_get_response.content
#     200
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/core.pyc in get(self, headers, redirect_limit, **kwargs)
#     232         kwargs.update(cache=True)
#     233         try:
# --> 234             response = self.__base.get(headers=headers, redirect_limit=redirect_limit, **kwargs)
#     235         except (ClientError, ServerError) as error:
#     236             if isinstance(error, JSONResponse):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in get(self, if_modified_since, headers, redirect_limit, **kwargs)
#     957             object from which content can be read
#     958         """
# --> 959         return self.__get_or_head("GET", if_modified_since, headers, redirect_limit, **kwargs)
#     960
#     961     def put(self, body=None, headers=None, **kwargs):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in __get_or_head(self, method, if_modified_since, headers, redirect_limit, **kwargs)
#     934             headers["If-Modified-Since"] = formatdate(datetime_to_timestamp(if_modified_since), usegmt=True)
#     935         rq = Request(method, self.uri, None, headers)
# --> 936         return rq.submit(redirect_limit=redirect_limit, **kwargs)
#     937
#     938     def head(self, if_modified_since=None, headers=None, redirect_limit=5, **kwargs):
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in submit(self, redirect_limit, **response_kwargs)
#     431         uri = self.uri
#     432         while True:
# --> 433             http, rs = submit(self.method, uri, self.body, self.headers)
#     434             status_class = rs.status // 100
#     435             if status_class == 3:
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/py2neo/packages/httpstream/http.pyc in submit(method, uri, body, headers)
#     360                                       host_port=uri.host_port)
#     361         else:
# --> 362             raise SocketError(code, description, host_port=uri.host_port)
#     363     else:
#     364         return http, response
#
# SocketError: Connection refused

# %%
query="""
MATCH p=shortestPath(
  (p1:Person {name:"Kevin Bacon"})-[*]-(p2:Person {name:"Michael Dorman"})
)
UNWIND nodes(p) as n
RETURN n.name, n.title
"""
result=graph.cypher.execute(query)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-839e6b8d927f> in <module>()
#       6 RETURN n.name, n.title
#       7 """
# ----> 8 result=graph.cypher.execute(query)
#       9 result
#
# NameError: name 'graph' is not defined

# %%
#now we bring it all together: bring in a second photo, and retrieve how the two actors/actresses know each other
urllib.urlretrieve("https://images-na.ssl-images-amazon.com/images/M/MV5BNjZjNjMyNDctZDNhOC00ODFlLTlmYzYtYjc2ZWMxNjNmYmE2XkEyXkFqcGdeQXVyNjI4OTg2Njg@._V1_SX640_CR0,0,640,999_AL_.jpg", "images/brad_pitt.jpg")                                                               
imshow(np.asarray(Image.open('images/brad_pitt.jpg', 'r')))

# %%
response = client.recognize_celebrities(
    Image={
        'Bytes': open('images/brad_pitt.jpg','rb').read().strip()
    }
)

print ('num celebrities found: '+str(len(response['CelebrityFaces'])))
for i in response['CelebrityFaces']:
    print i['Name']
    imageName = i['Name']
name2=response['CelebrityFaces'][0]['Name']
# Out:
# num celebrities found: 2
# Titus Welliver
# Jamie Hector

# %%
print "Querying Neo4j for connection between %s and %s!" % (name1, name2)
query="""
MATCH p=shortestPath(
  (p1:Person {name:"%s"})-[*]-(p2:Person {name:"%s"})
)
UNWIND nodes(p) as n
RETURN n.name, n.title
"""%(name1, name2)
print query
result=graph.cypher.execute(query)
print result
rekrelationships(graph,name1,name2)
# Out:
# Querying Neo4j for connection between Edward Norton and Titus Welliver!
#
# MATCH p=shortestPath(
#   (p1:Person {name:"Edward Norton"})-[*]-(p2:Person {name:"Titus Welliver"})
# )
# UNWIND nodes(p) as n
# RETURN n.name, n.title
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-af52c209f74e> in <module>()
#       8 """%(name1, name2)
#       9 print query
# ---> 10 result=graph.cypher.execute(query)
#      11 print result
#      12 rekrelationships(graph,name1,name2)
#
# NameError: name 'graph' is not defined
